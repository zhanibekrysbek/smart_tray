# %%
import numpy as np
import sys
sys.path.insert(1,'/home/zhanibek/.local/lib/python2.7/site-packages/cv2')
sys.path.insert(1,'/home/zhanibek/catkin_ws/src/smart_tray/scripts/')
import cv2 
import matplotlib.pyplot as plt
import os
from tqdm import tqdm_notebook
import pickle
import pandas as pd
from phri.utils import *

# %% [markdown]
# ### Constants

# %%
meta_data_paths = [
'/home/zhanibek/catkin_ws/src/smart_tray/data/rosbag/koh_sanket/trial_0/koh_sanket_trial_0_2020-10-11-20-48-27_meta_data.pkl',
'/home/zhanibek/catkin_ws/src/smart_tray/data/rosbag/koh_zhanibek/trial_0/koh_zhanibek_trial_0_2020-10-11-21-19-07_meta_data.pkl',
'/home/zhanibek/catkin_ws/src/smart_tray/data/rosbag/sanket_vignesh/trial_0/trial_0_2020-10-12-14-47-43_meta_data.pkl',
'/home/zhanibek/catkin_ws/src/smart_tray/data/rosbag/sanket_vignesh/trial_1/trial_1_2020-10-12-14-51-53_meta_data.pkl',
'/home/zhanibek/catkin_ws/src/smart_tray/data/rosbag/zhanibek_sanket/trial_0/trial_0_2020-10-12-15-02-32_meta_data.pkl',
'/home/zhanibek/catkin_ws/src/smart_tray/data/rosbag/zhanibek_vignesh/trial_0/trial_0_2020-10-12-14-57-11_meta_data.pkl'
]

meta_data_path = meta_data_paths[5]

# %%
meta_data = pickle.load(open(meta_data_path))

# %%
meta_data.keys()
# Out:
# ['camera_3',
#  '/cam1_tray_pose_estimation',
#  '/cam2_tray_pose_estimation',
#  'summary',
#  '/cam2_tray_grf',
#  '/cam3_tray_pose_estimation',
#  '/cam1_tray_grf',
#  'camera_1',
#  'camera_2',
#  '/RFT_FORCE',
#  '/imu_data',
#  '/RFT_FORCE_2',
#  '/cam3_tray_grf']

# %%
summary = meta_data['summary']
cam1_df = meta_data['camera_1']
cam2_df = meta_data['camera_2']
cam3_df = meta_data['camera_3']

rft1_df = meta_data['/RFT_FORCE']
rft2_df = meta_data['/RFT_FORCE_2']

imu_df = meta_data['/imu_data']

pose1_df = meta_data['/cam1_tray_pose_estimation']
pose2_df = meta_data['/cam2_tray_pose_estimation']
pose3_df = meta_data['/cam3_tray_pose_estimation']

grf1_df = meta_data['/cam1_tray_grf']
grf2_df = meta_data['/cam2_tray_grf']
grf3_df = meta_data['/cam3_tray_grf']

# %% [markdown]
# ### Summary

# %%
summary
# Out:
#                     topic_name  message_count    frequency  \
# 0   /cam1_tray_pose_estimation           4052    14.927252
# 1               /cam2_tray_grf           2749    29.619745
# 2   /cam2_tray_pose_estimation           8210    31.115707
# 3   /cam3_tray_pose_estimation           8222    29.990805
# 4               /cam1_tray_grf           2024    14.399116
# 5                 /RFT_FORCE_2         225699  1007.035774
# 6                   /RFT_FORCE         226904  1007.035774
# 7                    /imu_data          21198    77.264511
# 8               /cam3_tray_grf           3797    29.660590
# 9                    /camera_1           2190     8.195182
# 10                   /camera_2           4572    17.081534
# 11                   /camera_3           8046    30.003756
#
#                        msg_type    start_time      end_time
# 0     geometry_msgs/PoseStamped  1.602533e+09  1.602533e+09
# 1     geometry_msgs/PoseStamped  1.602533e+09  1.602533e+09
# 2     geometry_msgs/PoseStamped  1.602533e+09  1.602533e+09
# 3     geometry_msgs/PoseStamped  1.602533e+09  1.602533e+09
# 4     geometry_msgs/PoseStamped  1.602533e+09  1.602533e+09
# 5   geometry_msgs/WrenchStamped  1.602533e+09  1.602533e+09
# 6   geometry_msgs/WrenchStamped  1.602533e+09  1.602533e+09
# 7            smart_tray/imu_msg  1.602533e+09  1.602533e+09
# 8     geometry_msgs/PoseStamped  1.602533e+09  1.602533e+09
# 9             sensor_msgs/Image           NaN           NaN
# 10            sensor_msgs/Image           NaN           NaN
# 11            sensor_msgs/Image           NaN           NaN

# %%
t0 = summary.start_time[0]
tf = summary.end_time[0]
print t0, tf
print tf-t0
# Out:
# 1602532952.234247 1602533226.4826572
# 274.24841022491455

# %%
cam1_df.tail()
# Out:
#         seq    time_stamp        frame_id  \
# 2185  63087  1.602533e+09  angetube_63086
# 2186  63120  1.602533e+09  angetube_63119
# 2187  63121  1.602533e+09  angetube_63120
# 2188  63122  1.602533e+09  angetube_63121
# 2189  63123  1.602533e+09  angetube_63122
#
#                                              image_path
# 2185  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 2186  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 2187  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 2188  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 2189  /home/zhanibek/catkin_ws/src/smart_tray/data/r...

# %%
imu_delay = 52345.383253

# %% [markdown]
# ### Camera 1

# %%
cam1_df.head()
# Out:
#      seq    time_stamp        frame_id  \
# 0  54312  1.602533e+09  angetube_54311
# 1  54313  1.602533e+09  angetube_54312
# 2  54314  1.602533e+09  angetube_54313
# 3  54315  1.602533e+09  angetube_54314
# 4  54316  1.602533e+09  angetube_54315
#
#                                           image_path
# 0  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 1  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 2  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 3  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 4  /home/zhanibek/catkin_ws/src/smart_tray/data/r...

# %%
cam2_df.head()
# Out:
#      seq    time_stamp           frame_id  \
# 0  44376  1.602533e+09  logitech_t1_44375
# 1  44377  1.602533e+09  logitech_t1_44376
# 2  44378  1.602533e+09  logitech_t1_44377
# 3  44379  1.602533e+09  logitech_t1_44378
# 4  44380  1.602533e+09  logitech_t1_44379
#
#                                           image_path
# 0  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 1  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 2  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 3  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 4  /home/zhanibek/catkin_ws/src/smart_tray/data/r...

# %%
cam3_df.head()
# Out:
#      seq    time_stamp           frame_id  \
# 0  44540  1.602533e+09  logitech_t2_44539
# 1  44541  1.602533e+09  logitech_t2_44540
# 2  44542  1.602533e+09  logitech_t2_44541
# 3  44543  1.602533e+09  logitech_t2_44542
# 4  44544  1.602533e+09  logitech_t2_44543
#
#                                           image_path
# 0  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 1  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 2  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 3  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 4  /home/zhanibek/catkin_ws/src/smart_tray/data/r...

# %%
df = cam1_df
ind = np.random.randint(df.shape[0])
impath = df.image_path.iloc[ind]
im = read_image(impath)
plt.imshow(im)
print ind
# Out:
# 1465

# %% [markdown]
# ### Force Data

# %%
rft1_df.head()
# Out:
#        seq    time_stamp   frame_id  \
# 0  1270250  1.602533e+09  C00300119
# 1  1270251  1.602533e+09  C00300119
# 2  1270252  1.602533e+09  C00300119
# 3  1270253  1.602533e+09  C00300119
# 4  1270254  1.602533e+09  C00300119
#
#                                                force  \
# 0   [-0.03999999910593033, 0.0, 0.46000000834465027]
# 1   [-0.03999999910593033, 0.0, 0.46000000834465027]
# 2  [-0.019999999552965164, 0.0, 0.47999998927116394]
# 3  [-0.019999999552965164, 0.0, 0.47999998927116394]
# 4  [-0.019999999552965164, 0.0, 0.47999998927116394]
#
#                                               torque
# 0  [-0.0005000000237487257, 0.0, 0.46000000834465...
# 1  [-0.0005000000237487257, 0.0, 0.46000000834465...
# 2  [-0.0005000000237487257, 0.0, 0.47999998927116...
# 3  [-0.0005000000237487257, 0.0, 0.47999998927116...
# 4  [-0.0005000000237487257, 0.0, 0.47999998927116...

# %%
df = rft1_df
force1_x = df.force.apply(lambda x: x[0])
force1_y = df.force.apply(lambda x: x[1])
force1_z = df.force.apply(lambda x: x[2])

rft1_t_vec = df.time_stamp-t0

plt.figure(figsize=(20,10))
plt.plot(rft1_t_vec, force1_x)
plt.plot(rft1_t_vec, force1_y)
plt.plot(rft1_t_vec, force1_z)
plt.grid()
plt.legend(['force_x', 'force_y', 'force_z'])
plt.title('Force 1')
# Out:
# Text(0.5,1,'Force 1')

# %%
df = rft1_df
torque1_x = df.torque.apply(lambda x: x[0])
torque1_y = df.torque.apply(lambda x: x[1])
torque1_z = df.torque.apply(lambda x: x[2])

rft1_t_vec = df.time_stamp-t0

plt.figure(figsize=(15,6))
plt.plot(rft1_t_vec, torque1_x)
plt.plot(rft1_t_vec, torque1_y)
plt.plot(rft1_t_vec, force1_z)
plt.grid()
plt.legend(['force_x', 'force_y', 'force_z'])
plt.title('Force 1')
# Out:
# Text(0.5,1,'Force 1')

# %%
rft2_df.head()
# Out:
#        seq    time_stamp   frame_id  \
# 0  1271116  1.602533e+09  C00300122
# 1  1271117  1.602533e+09  C00300122
# 2  1271118  1.602533e+09  C00300122
# 3  1271119  1.602533e+09  C00300122
# 4  1271120  1.602533e+09  C00300122
#
#                                                force  \
# 0  [0.05999999865889549, -0.019999999552965164, 0...
# 1     [0.03999999910593033, 0.0, 0.5600000023841858]
# 2   [0.019999999552965164, 0.0, 0.47999998927116394]
# 3   [0.0, 0.019999999552965164, 0.41999998688697815]
# 4    [0.0, 0.03999999910593033, 0.36000001430511475]
#
#                                               torque
# 0  [0.0024999999441206455, -0.019999999552965164,...
# 1   [0.0024999999441206455, 0.0, 0.5600000023841858]
# 2  [0.0035000001080334187, 0.0, 0.47999998927116394]
# 3  [0.004000000189989805, 0.019999999552965164, 0...
# 4  [0.0044999998062849045, 0.03999999910593033, 0...

# %%
df = rft2_df
force2_x = df.force.apply(lambda x: x[0])
force2_y = df.force.apply(lambda x: x[1])
force2_z = df.force.apply(lambda x: x[2])

rft2_t_vec = df.time_stamp-t0

plt.figure(figsize=(20,10))
plt.plot(rft2_t_vec, force2_x)
plt.plot(rft2_t_vec, force2_y)
plt.plot(rft2_t_vec, force2_z)
plt.grid()
plt.legend(['force_x', 'force_y', 'force_z'])
plt.title('Force 2')
# Out:
# Text(0.5,1,'Force 2')

# %%
df = rft2_df
torque2_x = df.torque.apply(lambda x: x[0])
torque2_y = df.torque.apply(lambda x: x[1])
torque2_z = df.torque.apply(lambda x: x[2])

rft2_t_vec = df.time_stamp-t0

plt.figure(figsize=(15,6))
plt.plot(rft2_t_vec, torque2_x)
plt.plot(rft2_t_vec, torque2_y)
plt.plot(rft2_t_vec, torque2_z)
plt.grid()
plt.legend(['force_x', 'force_y', 'force_z'])
plt.title('Force 2')
# Out:
# Text(0.5,1,'Force 2')

# %% [markdown]
# ## Position Data

# %% [markdown]
# ### grf

# %%
df = grf1_df
grf1_x = df.position.apply(lambda x: x[0])
grf1_y = df.position.apply(lambda x: x[1])
grf1_z = df.position.apply(lambda x: x[2])

grf1_t_vec = df.time_stamp-t0

plt.figure(figsize=(10,4))
plt.plot(grf1_t_vec, grf1_x)
plt.plot(grf1_t_vec, grf1_y)
plt.plot(grf1_t_vec, grf1_z)
plt.grid()
plt.legend(['pos_x', 'pos_y', 'pos_z'])
plt.title('Linear Position')
# Out:
# Text(0.5,1,'Linear Position')

# %%
df = grf2_df
grf2_x = df.position.apply(lambda x: x[0])
grf2_y = df.position.apply(lambda x: x[1])
grf2_z = df.position.apply(lambda x: x[2])

grf2_t_vec = df.time_stamp-t0

plt.figure(figsize=(10,4))
plt.plot(grf2_t_vec, grf2_x)
plt.plot(grf2_t_vec, grf2_y)
plt.plot(grf2_t_vec, grf2_z)
plt.grid()
plt.legend(['pos_x', 'pos_y', 'pos_z'])
plt.title('Linear Position')
# Out:
# Text(0.5,1,'Linear Position')

# %%
df = grf3_df
grf3_x = df.position.apply(lambda x: x[0])
grf3_y = df.position.apply(lambda x: x[1])
grf3_z = df.position.apply(lambda x: x[2])

grf3_t_vec = df.time_stamp-t0

plt.figure(figsize=(10,4))
plt.plot(grf3_t_vec, grf3_x)
plt.plot(grf3_t_vec, grf3_y)
plt.plot(grf3_t_vec, grf3_z)
plt.grid()
plt.legend(['pos_x', 'pos_y', 'pos_z'])
plt.title('Linear Position')
# Out:
# Text(0.5,1,'Linear Position')

# %% [markdown]
# ### Raw Pose Data

# %%
df = pose1_df
pose1_x = df.position.apply(lambda x: x[0])
pose1_y = df.position.apply(lambda x: x[1])
pose1_z = df.position.apply(lambda x: x[2])

pose1_t_vec = df.time_stamp-t0

plt.figure(figsize=(10,4))
plt.plot(pose1_t_vec, pose1_x, '.', MarkerSize=1.2)
plt.plot(pose1_t_vec, pose1_y, '.', MarkerSize=1.2)
plt.plot(pose1_t_vec, pose1_z, '.', MarkerSize=1.2)
plt.grid()
plt.legend(['pos_x', 'pos_y', 'pos_z'])
plt.title('Linear Position')
# Out:
# Text(0.5,1,'Linear Position')

# %%
df = pose2_df
pose2_x = df.position.apply(lambda x: x[0])
pose2_y = df.position.apply(lambda x: x[1])
pose2_z = df.position.apply(lambda x: x[2])

pose2_t_vec = df.time_stamp-t0

plt.figure(figsize=(10,4))
plt.plot(pose2_t_vec, pose2_x, '.', MarkerSize=1.2)
plt.plot(pose2_t_vec, pose2_y, '.', MarkerSize=1.2)
plt.plot(pose2_t_vec, pose2_z, '.', MarkerSize=1.2)
plt.grid()
plt.legend(['pos_x', 'pos_y', 'pos_z'])
plt.title('Linear Position')
# Out:
# Text(0.5,1,'Linear Position')

# %%
df = pose3_df
pose3_x = df.position.apply(lambda x: x[0])
pose3_y = df.position.apply(lambda x: x[1])
pose3_z = df.position.apply(lambda x: x[2])

pose3_t_vec = df.time_stamp-t0

plt.figure(figsize=(10,4))
plt.plot(pose3_t_vec, pose3_x, '.', MarkerSize=1.2)
plt.plot(pose3_t_vec, pose3_y, '.', MarkerSize=1.2)
plt.plot(pose3_t_vec, pose3_z, '.', MarkerSize=1.2)
plt.grid()
plt.legend(['pos_x', 'pos_y', 'pos_z'])
plt.title('Linear Position')
# Out:
# Text(0.5,1,'Linear Position')

# %% [markdown]
# ### IMU Data

# %%
imu_df.head()
# Out:
#       seq    time_stamp                 frame_id  \
# 0  102467  1.602481e+09  LSM9DS1_IMU_SENSOR_DATA
# 1  102468  1.602481e+09  LSM9DS1_IMU_SENSOR_DATA
# 2  102469  1.602481e+09  LSM9DS1_IMU_SENSOR_DATA
# 3  102470  1.602481e+09  LSM9DS1_IMU_SENSOR_DATA
# 4  102471  1.602481e+09  LSM9DS1_IMU_SENSOR_DATA
#
#                                                accel  \
# 0  [0.19625146484375003, -0.0466695556640625, 10....
# 1  [0.24710931396484376, -0.017949829101562502, 1...
# 2  [0.2118079833984375, -0.03829296875, 10.488683...
# 3  [0.2865989379882813, 0.013761535644531251, 10....
# 4  [0.10530566406250001, 0.033506347656250005, 10...
#
#                                                 gyro  \
# 0  [5.749664306640625, -17.428436279296875, -4.65...
# 1  [5.5926513671875, -17.353668212890625, -4.8898...
# 2  [5.869293212890625, -17.293853759765625, -4.83...
# 3  [5.7720947265625, -17.21160888671875, -4.85244...
# 4  [5.63751220703125, -17.248992919921875, -4.927...
#
#                                                  mag
# 0  [-0.018200000748038292, 0.33235999941825867, -...
# 1  [-0.01372000016272068, 0.32899999618530273, -0...
# 2  [-0.012040000408887863, 0.3297000229358673, -0...
# 3  [-0.014420000836253166, 0.32774001359939575, -...
# 4  [-0.013300000689923763, 0.3304000198841095, -0...

# %%
df.time_stamp[0]
# Out:
# 1602532952.417042

# %%
df = imu_df
accel_x = df.accel.apply(lambda x: x[0])
accel_y = df.accel.apply(lambda x: x[1])
accel_z = df.accel.apply(lambda x: x[2])

imu_t_vec = df.time_stamp-t0 + imu_delay

plt.figure(figsize=(10,4))
plt.plot(imu_t_vec, accel_x)
plt.plot(imu_t_vec, accel_y)
plt.plot(imu_t_vec, accel_z)
plt.grid()
plt.legend(['accel_x', 'accel_y', 'accel_z'])
plt.title('Acceleration')
# Out:
# Text(0.5,1,'Acceleration')

# %% [markdown]
# ### Mix Plot

# %%
plt.figure(figsize=(20,8))

plt.plot(imu_t_vec, accel_z)
plt.plot(rft1_t_vec, force1_y)
plt.plot(rft2_t_vec, force2_y)
plt.plot(grf1_t_vec, grf1_x)
plt.plot(grf2_t_vec, grf2_x)
plt.plot(grf3_t_vec, grf3_x)
plt.grid()
plt.legend(['accel_z', 'force1_y', 'force2_y', 'grf1_z', 'grf2_z', 'grf3_z'])
plt.title('Mix Plot')
plt.xlabel('time, sec')
# Out:
# Text(0.5,0,'time, sec')
