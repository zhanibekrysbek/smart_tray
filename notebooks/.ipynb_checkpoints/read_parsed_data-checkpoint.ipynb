# %%
import numpy as np
import sys
sys.path.insert(1,'/home/zhanibek/.local/lib/python2.7/site-packages/cv2')
sys.path.insert(1,'/home/zhanibek/catkin_ws/src/smart_tray/scripts/')
import cv2 
import matplotlib.pyplot as plt
import os
from tqdm import tqdm_notebook
import pickle
import pandas as pd
from phri.utils import *

# %% [markdown]
# ### Constants

# %%
meta_data_path = '/home/zhanibek/catkin_ws/src/smart_tray/data/rosbag/parsed/test/test_1_2020-10-08-22-15-20_meta_data.pkl'

# %%
meta_data = pickle.load(open(meta_data_path))

# %%
meta_data.keys()
# Out:
# ['/cam1_pose_estimation',
#  '/camera_1',
#  'summary',
#  '/aruco_cam1_pose',
#  '/RFT_FORCE_2',
#  '/RFT_FORCE',
#  '/imu_data']

# %%
summary = meta_data['summary']
cam1_df = meta_data['/camera_1']
arcam1_df = meta_data['/aruco_cam1_pose']
rft1_df = meta_data['/RFT_FORCE']
rft2_df = meta_data['/RFT_FORCE_2']
imu_df = meta_data['/imu_data']
pose1_df = meta_data['/cam1_pose_estimation']

# %% [markdown]
# ### Summary

# %%
summary
# Out:
#               topic_name  message_count   frequency  \
# 0              /camera_1           1124   29.879493
# 1       /aruco_cam1_pose           1416   29.838468
# 2  /cam1_pose_estimation           1489   29.845794
# 3              /imu_data           3458   76.458866
# 4             /RFT_FORCE          44024  996.508434
# 5           /RFT_FORCE_2          44061  995.798670
#
#                       msg_type    start_time      end_time
# 0            sensor_msgs/Image  1.602213e+09  1.602213e+09
# 1            sensor_msgs/Image  1.602213e+09  1.602213e+09
# 2    geometry_msgs/PoseStamped  1.602213e+09  1.602213e+09
# 3           smart_tray/imu_msg  1.602213e+09  1.602213e+09
# 4  geometry_msgs/WrenchStamped  1.602213e+09  1.602213e+09
# 5  geometry_msgs/WrenchStamped  1.602213e+09  1.602213e+09

# %%
t0 = summary.start_time[0]
tf = summary.end_time[0]

# %% [markdown]
# ### Camera 1

# %%
cam1_df.head()
# Out:
#      seq    time_stamp        frame_id  \
# 0  51538  1.602213e+09  camera_1_51537
# 1  51539  1.602213e+09  camera_1_51538
# 2  51540  1.602213e+09  camera_1_51539
# 3  51541  1.602213e+09  camera_1_51540
# 4  51542  1.602213e+09  camera_1_51541
#
#                                           image_path
# 0  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 1  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 2  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 3  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 4  /home/zhanibek/catkin_ws/src/smart_tray/data/r...

# %%
df = cam1_df
ind = np.random.randint(df.shape[0])
impath = df.image_path.iloc[ind]
im = read_image(impath)
plt.imshow(im)
print ind
# Out:
# 379

# %%
arcam1_df.head()
# Out:
#      seq  time_stamp frame_id  \
# 0  51373         0.0
# 1  51374         0.0
# 2  51375         0.0
# 3  51376         0.0
# 4  51377         0.0
#
#                                           image_path
# 0  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 1  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 2  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 3  /home/zhanibek/catkin_ws/src/smart_tray/data/r...
# 4  /home/zhanibek/catkin_ws/src/smart_tray/data/r...

# %%
df = arcam1_df
ind = np.random.randint(df.shape[0])
impath = df.image_path.iloc[ind]
im = read_image(impath)
plt.imshow(im)
print ind
# Out:
# 1247

# %% [markdown]
# ### Force Data

# %%
rft1_df.head()
# Out:
#        seq    time_stamp   frame_id  \
# 0  1664273  1.602213e+09  C00300122
# 1  1664274  1.602213e+09  C00300122
# 2  1664275  1.602213e+09  C00300122
# 3  1664276  1.602213e+09  C00300122
# 4  1664277  1.602213e+09  C00300122
#
#                                                force  \
# 0                   [0.0, 0.0, -0.20000000298023224]
# 1                   [0.0, 0.0, -0.18000000715255737]
# 2                    [0.0, 0.0, -0.1599999964237213]
# 3  [-0.019999999552965164, 0.019999999552965164, ...
# 4  [-0.019999999552965164, 0.03999999910593033, -...
#
#                                               torque
# 0  [-0.001500000013038516, 0.0, -0.20000000298023...
# 1  [-0.001500000013038516, 0.0, -0.18000000715255...
# 2  [-0.0010000000474974513, 0.0, -0.1599999964237...
# 3  [-0.0010000000474974513, 0.019999999552965164,...
# 4   [0.0, 0.03999999910593033, -0.10000000149011612]

# %%
df = rft1_df
force1_x = df.force.apply(lambda x: x[0])
force1_y = df.force.apply(lambda x: x[1])
force1_z = df.force.apply(lambda x: x[2])

rft1_t_vec = df.time_stamp-t0

plt.figure(figsize=(10,4))
plt.plot(rft1_t_vec, force1_x)
plt.plot(rft1_t_vec, force1_y)
plt.plot(rft1_t_vec, force1_z)
plt.grid()
plt.legend(['force_x', 'force_y', 'force_z'])
plt.title('Force 1')

# %%
rft2_df.head()
# Out:
#        seq    time_stamp   frame_id  \
# 0  1664539  1.602213e+09  C00300119
# 1  1664540  1.602213e+09  C00300119
# 2  1664541  1.602213e+09  C00300119
# 3  1664542  1.602213e+09  C00300119
# 4  1664543  1.602213e+09  C00300119
#
#                                               force  \
# 0  [0.019999999552965164, 0.0, 0.47999998927116394]
# 1                  [0.019999999552965164, 0.0, 0.5]
# 2                    [0.0, 0.0, 0.5199999809265137]
# 3                    [0.0, 0.0, 0.5400000214576721]
# 4                    [0.0, 0.0, 0.5600000023841858]
#
#                                               torque
# 0  [-0.0010000000474974513, 0.0, 0.47999998927116...
# 1                  [-0.001500000013038516, 0.0, 0.5]
# 2  [-0.0020000000949949026, 0.0, 0.5199999809265137]
# 3  [-0.0024999999441206455, 0.0, 0.5400000214576721]
# 4  [-0.0024999999441206455, 0.0, 0.5600000023841858]

# %%
df = rft2_df
force2_x = df.force.apply(lambda x: x[0])
force2_y = df.force.apply(lambda x: x[1])
force2_z = df.force.apply(lambda x: x[2])

rft2_t_vec = df.time_stamp-t0

plt.figure(figsize=(10,4))
plt.plot(rft2_t_vec, force2_x)
plt.plot(rft2_t_vec, force2_y)
plt.plot(rft2_t_vec, force2_z)
plt.grid()
plt.legend(['force_x', 'force_y', 'force_z'])
plt.title('Force 2')

# %% [markdown]
# ### Position Data

# %%
pose1_df.head()
# Out:
#      seq    time_stamp        frame_id  \
# 0  51373  1.602213e+09  camera_1_51536
# 1  51374  1.602213e+09  camera_1_51537
# 2  51375  1.602213e+09  camera_1_51538
# 3  51376  1.602213e+09  camera_1_51539
# 4  51377  1.602213e+09  camera_1_51540
#
#                                             position  \
# 0  [-0.2797228359457306, -0.11320748549554417, 1....
# 1  [-0.2797228359457306, -0.11320748549554417, 1....
# 2  [-0.2797228359457306, -0.11320748549554417, 1....
# 3  [-0.2797228359457306, -0.11320748549554417, 1....
# 4  [-0.2797228359457306, -0.11320748549554417, 1....
#
#                                           quaternion
# 0  [-0.5872227432683191, 0.6109420736648671, -0.3...
# 1  [-0.5872227432683191, 0.6109420736648671, -0.3...
# 2  [-0.5872227432683191, 0.6109420736648671, -0.3...
# 3  [-0.5872227432683191, 0.6109420736648671, -0.3...
# 4  [-0.5872227432683191, 0.6109420736648671, -0.3...

# %%
df = pose1_df
pos_x = df.position.apply(lambda x: x[0])
pos_y = df.position.apply(lambda x: x[1])
pos_z = df.position.apply(lambda x: x[2])

pose1_t_vec = df.time_stamp-t0

plt.figure(figsize=(10,4))
plt.plot(pose1_t_vec, pos_x)
plt.plot(pose1_t_vec, pos_y)
plt.plot(pose1_t_vec, pos_z)
plt.grid()
plt.legend(['pos_x', 'pos_y', 'pos_z'])
plt.title('Linear Position')

# %% [markdown]
# ### IMU Data

# %%
imu_df.head()
# Out:
#       seq    time_stamp                 frame_id  \
# 0  174289  1.602213e+09  LSM9DS1_IMU_SENSOR_DATA
# 1  174290  1.602213e+09  LSM9DS1_IMU_SENSOR_DATA
# 2  174291  1.602213e+09  LSM9DS1_IMU_SENSOR_DATA
# 3  174292  1.602213e+09  LSM9DS1_IMU_SENSOR_DATA
# 4  174293  1.602213e+09  LSM9DS1_IMU_SENSOR_DATA
#
#                                                accel  \
# 0  [-0.0801759033203125, 0.04128460693359375, 9.7...
# 1  [-0.09992071533203126, 0.07299597167968751, 9....
# 2  [-0.11248559570312501, 0.04307958984375, 9.695...
# 3  [-0.088552490234375, 0.09992071533203126, 9.71...
# 4  [-0.07299597167968751, 0.04607122802734375, 9....
#
#                                                 gyro  \
# 0  [5.72723388671875, -20.972442626953125, -6.729...
# 1  [5.884246826171875, -21.03973388671875, -6.871...
# 2  [5.734710693359375, -21.12945556640625, -6.818...
# 3  [6.0711669921875, -21.121978759765625, -6.9010...
# 4  [5.749664306640625, -21.166839599609375, -6.82...
#
#                                                  mag
# 0  [-0.0509600006043911, 0.18900001049041748, -0....
# 1  [-0.05278000235557556, 0.193900004029274, -0.5...
# 2  [-0.05278000235557556, 0.19488000869750977, -0...
# 3  [-0.051100000739097595, 0.1888599991798401, -0...
# 4  [-0.050680000334978104, 0.18998000025749207, -...

# %%
accel_x = imu_df.accel.apply(lambda x: x[0])
accel_y = imu_df.accel.apply(lambda x: x[1])
accel_z = imu_df.accel.apply(lambda x: x[2])

imu_t_vec = imu_df.time_stamp-t0

plt.figure(figsize=(10,4))
plt.plot(imu_t_vec, accel_x)
plt.plot(imu_t_vec, accel_y)
plt.plot(imu_t_vec, accel_z)
plt.grid()
plt.legend(['accel_x', 'accel_y', 'accel_z'])
plt.title('Acceleration')

# %%
imu_df.accel

# %% [markdown]
# ### Mix Plot

# %%
plt.figure(figsize=(20,8))

plt.plot(imu_t_vec, accel_z)
plt.plot(rft1_t_vec, force1_y)
plt.plot(rft2_t_vec, force2_y)
plt.plot(pose1_t_vec, pos_z)
plt.grid()
plt.legend(['accel_z', 'force1_y', 'force2_y', 'pos_z'])
plt.title('Mix Plot')
plt.xlabel('time, sec')
