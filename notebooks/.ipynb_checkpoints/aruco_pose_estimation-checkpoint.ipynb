# %%
import numpy as np
import sys
# sys.path.pop(2)
sys.path.insert(1,'/home/zhanibek/.local/lib/python2.7/site-packages/cv2')
import cv2 
from cv2 import aruco
import matplotlib.pyplot as plt
import matplotlib as mpl
import os
from tqdm import tqdm_notebook

# %%
cv2.__version__
# Out:
# '4.2.0'

# %% [markdown]
# ### Functions

# %%
def showMarker(im):
    plt.imshow(im, interpolation='nearest', cmap='gray')

def read_image(fname):
    im = cv2.imread(fname)
    im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
    return im

# %% [markdown]
# ### Constants

# %%
base_dir = '../data/pose_estimation'

# %%
sqLength = 0.03677
mrkLegnth = 0.02959

# %%
'''
image 1: g_true = [[],
                   [],
                   [],
                   [0,0,0,1]]  # [R p]
                   
                   Euler angles, quaternion. Scipy -- how to compute Rotation matrices

'''
# Out:
# '\nimage 1: g_true = [[],\n                   [],\n                   [],\n                   [0,0,0,1]]  # [R p]\n                   \n                   Euler angles, quaternion. Scipy -- how to compute Rotation matrices\n\n'

# %%
vid = cv2.VideoCapture(1)

# %%
# res, im = vid.read()
# im0 = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
plt.imshow(im0)
vid.release()

# %% [markdown]
# ### Charuco Board for Calibration

# %%
aruco_dict = aruco.Dictionary_get(aruco.DICT_4X4_50)
calib_board = aruco.CharucoBoard_create(5, 7, sqLength, mrkLegnth, aruco_dict)
imboard = calib_board.draw((1000, 1400))

# cv2.imwrite(os.path.join(base_dir, "charuco_calibration.tiff"), imboard)

fig = plt.figure(figsize=(5,7))
showMarker(imboard)
plt.show()

# %% [markdown]
# ### Charuco Board for Detection 1

# %%
sqLen = 0.0644
mrklen = 0.04865 
aruco_dict = aruco.Dictionary_get(aruco.DICT_4X4_50)
board1 = aruco.CharucoBoard_create(2, 4, sqLen, mrklen, aruco_dict)
imboard1 = board1.draw((2000, 4000))

# cv2.imwrite(os.path.join(base_dir, "charuco_detection_1.tiff"), imboard)

fig = plt.figure(figsize=(5,7))
showMarker(imboard1)
plt.show()

# %% [markdown]
# ### Playing with Dictionaries

# %%
aruco_dict = aruco.Dictionary_get(aruco.DICT_4X4_50)
aruco_dict1 = aruco.custom_dictionary(16, 32, 0)

board = aruco.CharucoBoard_create(5, 7, 1, .8, aruco_dict)
imboard = board.draw((1000, 1400))

plt.figure(figsize=(5,7))
# plt.imshow(imboard, cmap = mpl.cm.gray, interpolation = "nearest")
showMarker(imboard)
plt.show()

# %% [markdown]
# # Calibrate

# %%
datadir = "/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/"
images = np.array([datadir + f for f in os.listdir(datadir) if f.endswith(".png") ])
order = np.argsort([int(p.split('/')[-1].split("_")[1].split("_")[0]) for p in images])
images = images[order]
len(images)
# Out:
# 49

# %%
images
# Out:
# array(['/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_0_10062020173227_878464.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_1_10062020173228_379042.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_2_10062020173228_879049.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_3_10062020173229_379010.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_4_10062020172536_634931.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_4_10062020173229_879060.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_5_10062020172537_134910.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_5_10062020173230_379073.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_6_10062020173230_878687.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_8_10062020173231_879054.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_9_10062020173232_378653.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_10_10062020173232_878642.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_10_10062020172539_634693.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_11_10062020173233_378664.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_12_10062020173233_878640.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_13_10062020173234_378661.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_13_10062020172541_134714.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_14_10062020173234_879066.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_15_10062020173235_378661.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_16_10062020173235_879030.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_17_10062020173236_378634.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_18_10062020173236_878675.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_19_10062020173237_378663.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_20_10062020173237_879059.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_21_10062020173238_379015.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_22_10062020173238_879053.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_23_10062020173239_378690.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_24_10062020173239_878663.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_25_10062020173240_378764.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_26_10062020173240_879032.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_27_10062020173241_379022.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_29_10062020173242_378653.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_29_10062020172549_134658.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_30_10062020173242_878982.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_33_10062020172551_134658.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_39_10062020172554_134884.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_44_10062020172556_634911.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_54_10062020172601_634913.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_55_10062020172602_134675.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_56_10062020172602_634903.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_65_10062020172607_134671.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_78_10062020172613_634684.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_80_10062020172614_634926.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_82_10062020172615_634913.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_87_10062020172618_134666.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_88_10062020172618_634685.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_92_10062020172620_634629.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_103_10062020172626_134945.png',
#        '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_107_10062020172628_135243.png'],
#       dtype='|S127')

# %%
im = read_image(images[20])
plt.figure()
plt.imshow(im)
#ax.axis('off')
plt.show()

# %%
class Calibrate_Camera:
    """Calibrate an individual camera"""
    def __init__(self, board):
#         self.dictionary = aruco.Dictionary_get(aruco.DICT_6X6_250)
#         self.row = 7  # horizontal
#         self.col = 5  # vertical
#         self.sqr = 1  # solid black squares
#         self.mrk = 0.8 # markers, must be smaller than squares
#         self.board = aruco.CharucoBoard_create(
#             self.col,self.row,
#             self.sqr,
#             self.mrk,
#             self.dictionary)
        self.board = board
        self.dictionary = self.board.dictionary

    def calculateReprojectionError(self, imgpoints, objpoints, rvecs, tvecs, mtx, dist):
        """
        imgpts: features found in image, (num_imgs, 2)
        objpts: calibration known features in 3d, (num_imgs, 3)
        """
        imgpoints = [c.reshape(-1,2) for c in imgpoints]
        mean_error = 0
        for i in range(len(objpoints)):
            imgpoints2, _ = cv2.projectPoints(objpoints[i], rvecs[i], tvecs[i], mtx, dist)
            imgpoints2 = imgpoints2.reshape(-1,2)

            # if not all markers were found, then the norm below will fail
            if len(imgpoints[i]) != len(imgpoints2):
                continue
                
            error = cv2.norm(imgpoints[i], imgpoints2, cv2.NORM_L2)/len(imgpoints2)
            mean_error += error

        total_error = mean_error/len(objpoints)
        return total_error

    def calibrate(self, images):
        corners_all = []  # corners in all images
        ids_all = []  # ids found in all images
        image_size = None

#         images = glob.glob('./calib_images/*.jpg')

        for imname in tqdm_notebook(images):

            img = cv2.imread(imname)

            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
              
            corners, ids, rejectedImgPts = aruco.detectMarkers(gray, self.dictionary)
            
            # if ids were found, then
            if ids is not None and len(ids) > 0:
                ret, ch_corners, ch_ids = aruco.interpolateCornersCharuco(
                    corners, ids, gray, self.board)

                corners_all.append(ch_corners)
                ids_all.append(ch_ids)

        image_size = gray.shape[::-1]

        # Make sure at least one image was found
        if len(images) < 1:
            #Calibration failed because there were no images, warn the user
            print("Calibration was unsuccessful. No images of charucoboards were found. Add images of charucoboards and use or alter the naming conventions used in this file.")
            # Exit for failure
            exit()

        rms, cameraMatrix, distCoeffs, rvecs, tvecs = aruco.calibrateCameraCharuco(
            corners_all, ids_all, self.board, image_size, None, None)

        h, w = self.board.chessboardCorners.shape
        objpts = [self.board.chessboardCorners.reshape((h,1,3)) for c in corners_all]
        imgpts = corners_all
        
        rep_error = self.calculateReprojectionError(imgpts, objpts, rvecs, tvecs, cameraMatrix, distCoeffs)
        
        cam_cal_data = {
            'cameraMatrix': cameraMatrix,
            'distCoeffs': distCoeffs,
            'rotationVector': rvecs,
            'translationVector': tvecs,
            'reprojectionError': rep_error,
            'rms': rms
        }

        return cam_cal_data

# %%
calib = Calibrate_Camera(calib_board)

# %%
# %time cam_cal_data = calib.calibrate(images)
# Out:
# /home/zhanibek/.local/lib/python2.7/site-packages/ipykernel_launcher.py:45: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(HTML(value=u''), FloatProgress(value=0.0, max=49.0), HTML(value=u'')))
# CPU times: user 17.7 s, sys: 18.2 ms, total: 17.7 s
# Wall time: 17.4 s

# %% [markdown]
# #### Visualize Calibration

# %%
ind = 0
img = read_image(images[ind])
plt.imshow(img)
images[ind]
# Out:
# '/home/zhanibek/catkin_ws/src/smart_tray/data/pose_estimation/calibration/logitech_t1/images/calib_0_10062020173227_878464.png'

# %%
a,b,c = aruco.detectMarkers(img, calib_board.dictionary)

# %%
plt.figure(figsize=(10,15))
plt.imshow(aruco.drawDetectedMarkers(img, c))

# %%
len(cam_cal_data['rotationVector']), cam_cal_data['rotationVector'][ind].shape
# Out:
# (49, (3, 1))

# %%
plt.imshow(aruco.drawAxis(img.copy(), cam_cal_data['cameraMatrix'], cam_cal_data['distCoeffs'],
          cam_cal_data['rotationVector'][ind], cam_cal_data['translationVector'][ind], 0.09))

# %% [markdown]
# ## Pose Estimation

# %%
cam_cal_data.keys()
# Out:
# ['rms',
#  'rotationVector',
#  'cameraMatrix',
#  'translationVector',
#  'distCoeffs',
#  'reprojectionError']

# %%
camera_matrix = cam_cal_data['cameraMatrix']
dist_coeffs = cam_cal_data['distCoeffs']

# %%
frame = im0.copy()
corners, ids, rejectedImgPoints = aruco.detectMarkers(im0, board1.dictionary)
retval,rvec,tvec = aruco.estimatePoseBoard( corners, ids, board1, camera_matrix, dist_coeffs, None, None, False )
frame = aruco.drawAxis( frame, camera_matrix, dist_coeffs, rvec, tvec, mrklen )
frame = aruco.drawDetectedMarkers( frame, corners, ids )

# %%
plt.imshow(frame)

# %%
ret, ch_corners, ch_ids = aruco.interpolateCornersCharuco(corners, ids, im0, board1)
retval,rvec,tvec = aruco.estimatePoseCharucoBoard(ch_corners, ch_ids, board1, camera_matrix, dist_coeffs, None,None, False)
# Out:
# (False, None, None)

# %%
help(aruco.CharucoBoard_create)
# Out:
# Help on built-in function CharucoBoard_create:
#
# CharucoBoard_create(...)
#     CharucoBoard_create(squaresX, squaresY, squareLength, markerLength, dictionary) -> retval
#     .   * @brief Create a CharucoBoard object
#     .        *
#     .        * @param squaresX number of chessboard squares in X direction
#     .        * @param squaresY number of chessboard squares in Y direction
#     .        * @param squareLength chessboard square side length (normally in meters)
#     .        * @param markerLength marker side length (same unit than squareLength)
#     .        * @param dictionary dictionary of markers indicating the type of markers.
#     .        * The first markers in the dictionary are used to fill the white chessboard squares.
#     .        * @return the output CharucoBoard object
#     .        *
#     .        * This functions creates a CharucoBoard object given the number of squares in each direction
#     .        * and the size of the markers and chessboard squares.

# %%
help(aruco.estimatePoseCharucoBoard)
# Out:
# Help on built-in function estimatePoseCharucoBoard:
#
# estimatePoseCharucoBoard(...)
#     estimatePoseCharucoBoard(charucoCorners, charucoIds, board, cameraMatrix, distCoeffs[, rvec[, tvec[, useExtrinsicGuess]]]) -> retval, rvec, tvec
#     .   * @brief Pose estimation for a ChArUco board given some of their corners
#     .   * @param charucoCorners vector of detected charuco corners
#     .   * @param charucoIds list of identifiers for each corner in charucoCorners
#     .   * @param board layout of ChArUco board.
#     .   * @param cameraMatrix input 3x3 floating-point camera matrix
#     .   * \f$A = \vecthreethree{f_x}{0}{c_x}{0}{f_y}{c_y}{0}{0}{1}\f$
#     .   * @param distCoeffs vector of distortion coefficients
#     .   * \f$(k_1, k_2, p_1, p_2[, k_3[, k_4, k_5, k_6],[s_1, s_2, s_3, s_4]])\f$ of 4, 5, 8 or 12 elements
#     .   * @param rvec Output vector (e.g. cv::Mat) corresponding to the rotation vector of the board
#     .   * (see cv::Rodrigues).
#     .   * @param tvec Output vector (e.g. cv::Mat) corresponding to the translation vector of the board.
#     .   * @param useExtrinsicGuess defines whether initial guess for \b rvec and \b tvec will be used or not.
#     .   *
#     .   * This function estimates a Charuco board pose from some detected corners.
#     .   * The function checks if the input corners are enough and valid to perform pose estimation.
#     .   * If pose estimation is valid, returns true, else returns false.
